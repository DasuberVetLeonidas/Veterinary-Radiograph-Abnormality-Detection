# %%
from __future__ import print_function
from __future__ import division
import torch
import torch.nn as nn
from torchvision.transforms.functional import pad as PAD
import torch.optim as optim
from torch.utils.data.dataset import random_split
import numpy as np
import torchvision
from torchvision import datasets, models, transforms
import matplotlib.pyplot as plt
import time
import os
import copy
print("PyTorch Version: ",torch.__version__)
import re
import pandas as pd
from sklearn.metrics import classification_report
import wandb
import numbers
import natsort
from PIL import Image
from torchvision.transforms import ToPILImage,ToTensor
ToPILImage = ToPILImage()
os.environ['CUDA_VISIBLE_DEVICES']='1'

from efficientnet_pytorch import EfficientNet
# Out:
# PyTorch Version:  1.4.0

# %%
hyperparameter_defaults = dict(
    input_size = 1024,
    batch_size = 1,
)
os.environ['WANDB_NOTEBOOK_NAME']='GCAM Upload Notebook'
wandb.init(project="GCAM Results",config=hyperparameter_defaults)
# Out:
# Failed to query for notebook name, you can set it manually with the WANDB_NOTEBOOK_NAME environment variable
# wandb: Currently logged in as: szho6430 (use `wandb login --relogin` to force relogin)
#                 Tracking run with wandb version 0.10.8<br/>
#                 Syncing run <strong style="color:#cdcd00">happy-sky-19</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/szho6430/GCAM%20Results" target="_blank">https://wandb.ai/szho6430/GCAM%20Results</a><br/>
#                 Run page: <a href="https://wandb.ai/szho6430/GCAM%20Results/runs/md87gr2z" target="_blank">https://wandb.ai/szho6430/GCAM%20Results/runs/md87gr2z</a><br/>
#                 Run data is saved locally in <code>wandb/run-20201028_174654-md87gr2z</code><br/><br/>
# <h1>Run(md87gr2z)</h1><p></p><iframe src="https://wandb.ai/szho6430/GCAM%20Results/runs/md87gr2z" style="border:none;width:100%;height:400px"></iframe>

# %%
from torch.utils.data import Dataset

class TestSet(Dataset):
    def __init__(self, main_dir, transform):
        self.main_dir = main_dir
        self.transform = transform
        all_imgs = os.listdir(main_dir)
        self.total_imgs = natsort.natsorted(all_imgs)

    def __len__(self):
        return len(self.total_imgs)

    def __getitem__(self, idx):
        if torch.is_tensor(idx):
            idx = idx.tolist()
        img_loc = os.path.join(self.main_dir, self.total_imgs[idx])
        img_name = self.total_imgs[idx]
        image = Image.open(img_loc).convert("RGB")
        tensor_image = self.transform(image)
        return tensor_image,img_name

# %%
test_transform = transforms.Compose([
        transforms.Resize(1024),
        transforms.ToTensor()
    ])

# %%
GradCam_Sets = {x: TestSet(os.path.join('./grad-cam-pytorch/outputs/',x),transform=test_transform) for x in ['Direct','MURA','MURA2'] }

# %%
CamLoaders = {x:torch.utils.data.DataLoader(GradCam_Sets[x],batch_size=1,shuffle=False) for x in ['Direct','MURA','MURA2']}

# %%
LIST=pd.read_csv('./Post-Meta-Dz-Consolidated.csv',dtype={'Image No.':str})
LIST.head()
# Out:
#    Patient No. Species            Breed Age (yrs)  Gender  Image Findings  \
# 0            1  Canine  German Shepherd         2  Female  Osteoarthrosis
# 1            1  Canine  German Shepherd         2  Female  Osteoarthrosis
# 2            1  Canine  German Shepherd         2  Female  Osteoarthrosis
# 3            1  Canine  German Shepherd         2  Female  Osteoarthrosis
# 4            1  Canine  German Shepherd         2  Female  Osteoarthrosis
#
#   Thoracic or Pelvic Image No.  Is_Normal  Test_CV  Direct  MURA
# 0           Thoracic       001      False        4       1     1
# 1           Thoracic       002      False        1       1     1
# 2           Thoracic       003      False        3       0     0
# 3           Thoracic       004      False        3       1     1
# 4           Thoracic       005      False        4       1     1

# %%
for strategy in [
#     'Direct',
    'MURA',
]:
    for inputs,name in CamLoaders['MURA2']:
        inputs = ToPILImage(inputs.squeeze())
        name = name[0].split('-')[1]
        image_no = name.replace('.jpeg','').replace('.jpg','')
        correctness = LIST.loc[LIST['Image No.']==image_no,strategy].item()
        normal = LIST.loc[LIST['Image No.']==image_no,'Is_Normal'].item()
        if normal:
            if correctness == 1:
                caption = strategy+'_Finetune\nPrediction\tNormal'
            if correctness == 0:
                caption = strategy+'_Finetune\nPrediction\tAbnormal'
        if normal==False:
            if correctness == 1:
                caption = strategy+'_Finetune\nPrediction\tAbnormal'
            if correctness == 0:
                caption = strategy+'_Finetune\nPrediction\tNormal'
        wandb.log({image_no:[wandb.Image(inputs,caption=caption)]})
        print(f"{image_no}\t{caption}")
# Out:
# /home/dasleo/miniconda3/envs/pytorch13/lib/python3.7/site-packages/ipykernel_launcher.py:9: FutureWarning: `item` has been deprecated and will be removed in a future version
#   if __name__ == '__main__':
# /home/dasleo/miniconda3/envs/pytorch13/lib/python3.7/site-packages/ipykernel_launcher.py:10: FutureWarning: `item` has been deprecated and will be removed in a future version
#   # Remove the CWD from sys.path while we load stuff.
# 001	MURA_Finetune
# Prediction	Abnormal
# 002	MURA_Finetune
# Prediction	Abnormal
# 003	MURA_Finetune
# Prediction	Normal
# 004	MURA_Finetune
# Prediction	Abnormal
# 005	MURA_Finetune
# Prediction	Abnormal
# 006	MURA_Finetune
# Prediction	Abnormal
# 007	MURA_Finetune
# Prediction	Abnormal
# 008	MURA_Finetune
# Prediction	Abnormal
# 009	MURA_Finetune
# Prediction	Abnormal
# 010	MURA_Finetune
# Prediction	Abnormal
# 011	MURA_Finetune
# Prediction	Normal
# 012	MURA_Finetune
# Prediction	Normal
# 013	MURA_Finetune
# Prediction	Abnormal
# 014	MURA_Finetune
# Prediction	Abnormal
# 015	MURA_Finetune
# Prediction	Abnormal
# 016	MURA_Finetune
# Prediction	Abnormal
# 017	MURA_Finetune
# Prediction	Normal
# 018	MURA_Finetune
# Prediction	Abnormal
# 019	MURA_Finetune
# Prediction	Normal
# 020	MURA_Finetune
# Prediction	Abnormal
# 021	MURA_Finetune
# Prediction	Abnormal
# 022	MURA_Finetune
# Prediction	Abnormal
# 023	MURA_Finetune
# Prediction	Abnormal
# 024	MURA_Finetune
# Prediction	Abnormal
# 025	MURA_Finetune
# Prediction	Abnormal
# 026	MURA_Finetune
# Prediction	Abnormal
# 027	MURA_Finetune
# Prediction	Normal
# 028	MURA_Finetune
# Prediction	Normal
# 029	MURA_Finetune
# Prediction	Abnormal
# 030	MURA_Finetune
# Prediction	Normal
# 031	MURA_Finetune
# Prediction	Normal
# 032	MURA_Finetune
# Prediction	Normal
# 033	MURA_Finetune
# Prediction	Normal
# 034	MURA_Finetune
# Prediction	Abnormal
# 035	MURA_Finetune
# Prediction	Abnormal
# 036	MURA_Finetune
# Prediction	Normal
# 037	MURA_Finetune
# Prediction	Abnormal
# 038	MURA_Finetune
# Prediction	Abnormal
# 039	MURA_Finetune
# Prediction	Abnormal
# 040	MURA_Finetune
# Prediction	Abnormal
# 041	MURA_Finetune
# Prediction	Normal
# 042	MURA_Finetune
# Prediction	Normal
# 043	MURA_Finetune
# Prediction	Abnormal
# 044	MURA_Finetune
# Prediction	Abnormal
# 045	MURA_Finetune
# Prediction	Normal
# 046	MURA_Finetune
# Prediction	Abnormal
# 047	MURA_Finetune
# Prediction	Abnormal
# 048	MURA_Finetune
# Prediction	Normal
# 049	MURA_Finetune
# Prediction	Abnormal
# 050	MURA_Finetune
# Prediction	Abnormal
# 051	MURA_Finetune
# Prediction	Abnormal
# 052	MURA_Finetune
# Prediction	Abnormal
# 053	MURA_Finetune
# Prediction	Abnormal
# 054	MURA_Finetune
# Prediction	Abnormal
# 055	MURA_Finetune
# Prediction	Abnormal
# 056	MURA_Finetune
# Prediction	Abnormal
# 057	MURA_Finetune
# Prediction	Abnormal
# 058	MURA_Finetune
# Prediction	Abnormal
# 059	MURA_Finetune
# Prediction	Abnormal
# 060	MURA_Finetune
# Prediction	Normal
# 061	MURA_Finetune
# Prediction	Normal
# 062	MURA_Finetune
# Prediction	Abnormal
# 063	MURA_Finetune
# Prediction	Abnormal
# 064	MURA_Finetune
# Prediction	Abnormal
# 065	MURA_Finetune
# Prediction	Abnormal
# 066	MURA_Finetune
# Prediction	Abnormal
# 067	MURA_Finetune
# Prediction	Abnormal
# 068	MURA_Finetune
# Prediction	Abnormal
# 069	MURA_Finetune
# Prediction	Abnormal
# 070	MURA_Finetune
# Prediction	Abnormal
# 071	MURA_Finetune
# Prediction	Abnormal
# 072	MURA_Finetune
# Prediction	Abnormal
# 073	MURA_Finetune
# Prediction	Abnormal
# 074	MURA_Finetune
# Prediction	Abnormal
# 075	MURA_Finetune
# Prediction	Abnormal
# 076	MURA_Finetune
# Prediction	Abnormal
# 077	MURA_Finetune
# Prediction	Normal
# 078	MURA_Finetune
# Prediction	Abnormal
# 079	MURA_Finetune
# Prediction	Abnormal
# 080	MURA_Finetune
# Prediction	Abnormal
# 081	MURA_Finetune
# Prediction	Abnormal
# 082	MURA_Finetune
# Prediction	Abnormal
# 083	MURA_Finetune
# Prediction	Abnormal
# 084	MURA_Finetune
# Prediction	Abnormal
# 085	MURA_Finetune
# Prediction	Abnormal
# 086	MURA_Finetune
# Prediction	Abnormal
# 087	MURA_Finetune
# Prediction	Abnormal
# 088	MURA_Finetune
# Prediction	Normal
# 089	MURA_Finetune
# Prediction	Abnormal
# 090	MURA_Finetune
# Prediction	Abnormal
# 091	MURA_Finetune
# Prediction	Abnormal
# 092	MURA_Finetune
# Prediction	Abnormal
# 093	MURA_Finetune
# Prediction	Normal
# 094	MURA_Finetune
# Prediction	Abnormal
# 095	MURA_Finetune
# Prediction	Abnormal
# 096	MURA_Finetune
# Prediction	Abnormal
# 097	MURA_Finetune
# Prediction	Abnormal
# 098	MURA_Finetune
# Prediction	Abnormal
# 099	MURA_Finetune
# Prediction	Abnormal
# 100	MURA_Finetune
# Prediction	Abnormal
# 101	MURA_Finetune
# Prediction	Abnormal
# 102	MURA_Finetune
# Prediction	Abnormal
# 103	MURA_Finetune
# Prediction	Abnormal
# 104	MURA_Finetune
# Prediction	Abnormal
# 105	MURA_Finetune
# Prediction	Abnormal
# 106	MURA_Finetune
# Prediction	Normal
# 107	MURA_Finetune
# Prediction	Abnormal
# 108	MURA_Finetune
# Prediction	Normal
# 109	MURA_Finetune
# Prediction	Abnormal
# 110	MURA_Finetune
# Prediction	Normal
# 111	MURA_Finetune
# Prediction	Normal
# 112	MURA_Finetune
# Prediction	Normal
# 113	MURA_Finetune
# Prediction	Normal
# 114	MURA_Finetune
# Prediction	Normal
# 115	MURA_Finetune
# Prediction	Abnormal
# 116	MURA_Finetune
# Prediction	Normal
# 117	MURA_Finetune
# Prediction	Abnormal
# 118	MURA_Finetune
# Prediction	Abnormal
# 119	MURA_Finetune
# Prediction	Abnormal
# 120	MURA_Finetune
# Prediction	Normal
# 121	MURA_Finetune
# Prediction	Abnormal
# 122	MURA_Finetune
# Prediction	Abnormal
# 123	MURA_Finetune
# Prediction	Normal
# 124	MURA_Finetune
# Prediction	Abnormal
# 125	MURA_Finetune
# Prediction	Abnormal
# 126	MURA_Finetune
# Prediction	Abnormal
# 127	MURA_Finetune
# Prediction	Abnormal
# 128	MURA_Finetune
# Prediction	Abnormal
# 129	MURA_Finetune
# Prediction	Abnormal
# 130	MURA_Finetune
# Prediction	Abnormal
# 131	MURA_Finetune
# Prediction	Abnormal
# 132	MURA_Finetune
# Prediction	Abnormal
# 133	MURA_Finetune
# Prediction	Abnormal
# 134	MURA_Finetune
# Prediction	Abnormal
# 135	MURA_Finetune
# Prediction	Abnormal
# 136	MURA_Finetune
# Prediction	Abnormal
# 137	MURA_Finetune
# Prediction	Abnormal
# 138	MURA_Finetune
# Prediction	Abnormal
# 139	MURA_Finetune
# Prediction	Abnormal
# 140	MURA_Finetune
# Prediction	Abnormal
# 141	MURA_Finetune
# Prediction	Abnormal
# 142	MURA_Finetune
# Prediction	Abnormal
# 143	MURA_Finetune
# Prediction	Abnormal
# 144	MURA_Finetune
# Prediction	Abnormal
# 145	MURA_Finetune
# Prediction	Abnormal
# 146	MURA_Finetune
# Prediction	Abnormal
# 147	MURA_Finetune
# Prediction	Abnormal
# 148	MURA_Finetune
# Prediction	Abnormal
# 149	MURA_Finetune
# Prediction	Normal
# 150	MURA_Finetune
# Prediction	Normal
# 151	MURA_Finetune
# Prediction	Abnormal
# 152	MURA_Finetune
# Prediction	Abnormal
# 153	MURA_Finetune
# Prediction	Abnormal
# 154	MURA_Finetune
# Prediction	Abnormal
# 155	MURA_Finetune
# Prediction	Abnormal
# 156	MURA_Finetune
# Prediction	Abnormal
# 157	MURA_Finetune
# Prediction	Abnormal
# 158	MURA_Finetune
# Prediction	Abnormal
# 159	MURA_Finetune
# Prediction	Abnormal
# 160	MURA_Finetune
# Prediction	Abnormal
# 161	MURA_Finetune
# Prediction	Normal
# 162	MURA_Finetune
# Prediction	Normal
# 163	MURA_Finetune
# Prediction	Abnormal
# 164	MURA_Finetune
# Prediction	Abnormal
# 165	MURA_Finetune
# Prediction	Abnormal
# 166	MURA_Finetune
# Prediction	Abnormal
# 167	MURA_Finetune
# Prediction	Normal
# 168	MURA_Finetune
# Prediction	Normal
# 169	MURA_Finetune
# Prediction	Abnormal
# 170	MURA_Finetune
# Prediction	Abnormal
# 171	MURA_Finetune
# Prediction	Abnormal
# 172	MURA_Finetune
# Prediction	Abnormal
# 173	MURA_Finetune
# Prediction	Abnormal
# 174	MURA_Finetune
# Prediction	Abnormal
# 175	MURA_Finetune
# Prediction	Abnormal
# 176	MURA_Finetune
# Prediction	Abnormal
# 177	MURA_Finetune
# Prediction	Abnormal
# 178	MURA_Finetune
# Prediction	Abnormal
# 179	MURA_Finetune
# Prediction	Abnormal
# 180	MURA_Finetune
# Prediction	Abnormal
# 181	MURA_Finetune
# Prediction	Abnormal
# 182	MURA_Finetune
# Prediction	Abnormal
# 183	MURA_Finetune
# Prediction	Abnormal
# 184	MURA_Finetune
# Prediction	Abnormal
# 185	MURA_Finetune
# Prediction	Abnormal
# 186	MURA_Finetune
# Prediction	Abnormal
# 187	MURA_Finetune
# Prediction	Abnormal
# 188	MURA_Finetune
# Prediction	Abnormal
# 189	MURA_Finetune
# Prediction	Abnormal
# 190	MURA_Finetune
# Prediction	Abnormal
# 191	MURA_Finetune
# Prediction	Normal
# 192	MURA_Finetune
# Prediction	Abnormal
# 193	MURA_Finetune
# Prediction	Abnormal
# 194	MURA_Finetune
# Prediction	Abnormal
# 195	MURA_Finetune
# Prediction	Abnormal
# 196	MURA_Finetune
# Prediction	Abnormal
# 197	MURA_Finetune
# Prediction	Abnormal
# 198	MURA_Finetune
# Prediction	Abnormal
# 199	MURA_Finetune
# Prediction	Abnormal
# 200	MURA_Finetune
# Prediction	Abnormal
# 201	MURA_Finetune
# Prediction	Abnormal
# 202	MURA_Finetune
# Prediction	Abnormal
# 203	MURA_Finetune
# Prediction	Abnormal
# 204	MURA_Finetune
# Prediction	Abnormal
# 205	MURA_Finetune
# Prediction	Abnormal
# 206	MURA_Finetune
# Prediction	Abnormal
# 207	MURA_Finetune
# Prediction	Abnormal
# 208	MURA_Finetune
# Prediction	Abnormal
# 209	MURA_Finetune
# Prediction	Abnormal
# 210	MURA_Finetune
# Prediction	Abnormal
# 211	MURA_Finetune
# Prediction	Abnormal
# 212	MURA_Finetune
# Prediction	Abnormal
# 213	MURA_Finetune
# Prediction	Abnormal
# 214	MURA_Finetune
# Prediction	Normal
# 215	MURA_Finetune
# Prediction	Normal
# 216	MURA_Finetune
# Prediction	Abnormal
# 217	MURA_Finetune
# Prediction	Abnormal
# 218	MURA_Finetune
# Prediction	Abnormal
# 219	MURA_Finetune
# Prediction	Abnormal
# 220	MURA_Finetune
# Prediction	Abnormal
# 221	MURA_Finetune
# Prediction	Abnormal
# 222	MURA_Finetune
# Prediction	Abnormal
# 223	MURA_Finetune
# Prediction	Abnormal
# 224	MURA_Finetune
# Prediction	Abnormal
# 225	MURA_Finetune
# Prediction	Abnormal
# 226	MURA_Finetune
# Prediction	Abnormal
# 227	MURA_Finetune
# Prediction	Abnormal
# 228	MURA_Finetune
# Prediction	Abnormal
# 229	MURA_Finetune
# Prediction	Abnormal
# 230	MURA_Finetune
# Prediction	Abnormal
# 231	MURA_Finetune
# Prediction	Abnormal
# 232	MURA_Finetune
# Prediction	Abnormal
# 233	MURA_Finetune
# Prediction	Abnormal
# 234	MURA_Finetune
# Prediction	Abnormal
# 235	MURA_Finetune
# Prediction	Abnormal
# 236	MURA_Finetune
# Prediction	Abnormal
# 237	MURA_Finetune
# Prediction	Normal
# 238	MURA_Finetune
# Prediction	Normal
# 239	MURA_Finetune
# Prediction	Normal
# 240	MURA_Finetune
# Prediction	Normal
# 241	MURA_Finetune
# Prediction	Normal
# 242	MURA_Finetune
# Prediction	Normal
# 243	MURA_Finetune
# Prediction	Normal
# 244	MURA_Finetune
# Prediction	Abnormal
# 245	MURA_Finetune
# Prediction	Abnormal
# 246	MURA_Finetune
# Prediction	Normal
# 247	MURA_Finetune
# Prediction	Normal
# 248	MURA_Finetune
# Prediction	Abnormal
# 249	MURA_Finetune
# Prediction	Normal
# 250	MURA_Finetune
# Prediction	Normal
# 251	MURA_Finetune
# Prediction	Abnormal
# 252	MURA_Finetune
# Prediction	Abnormal
# 253	MURA_Finetune
# Prediction	Normal
# 254	MURA_Finetune
# Prediction	Normal
# 255	MURA_Finetune
# Prediction	Normal
# 256	MURA_Finetune
# Prediction	Normal
# 257	MURA_Finetune
# Prediction	Abnormal
# 258	MURA_Finetune
# Prediction	Normal
# 259	MURA_Finetune
# Prediction	Abnormal
# 260	MURA_Finetune
# Prediction	Abnormal
# 261	MURA_Finetune
# Prediction	Abnormal
# 262	MURA_Finetune
# Prediction	Abnormal
# 263	MURA_Finetune
# Prediction	Normal
# 264	MURA_Finetune
# Prediction	Abnormal
# 265	MURA_Finetune
# Prediction	Normal
# 266	MURA_Finetune
# Prediction	Normal
# 267	MURA_Finetune
# Prediction	Abnormal
# 268	MURA_Finetune
# Prediction	Normal
# 269	MURA_Finetune
# Prediction	Abnormal
# 270	MURA_Finetune
# Prediction	Normal
# 271	MURA_Finetune
# Prediction	Abnormal
# 272	MURA_Finetune
# Prediction	Normal
# 273	MURA_Finetune
# Prediction	Abnormal
# 274	MURA_Finetune
# Prediction	Abnormal
# 275	MURA_Finetune
# Prediction	Abnormal
# 276	MURA_Finetune
# Prediction	Abnormal
# 277	MURA_Finetune
# Prediction	Abnormal
# 278	MURA_Finetune
# Prediction	Abnormal
# 279	MURA_Finetune
# Prediction	Normal
# 280	MURA_Finetune
# Prediction	Abnormal
# 281	MURA_Finetune
# Prediction	Abnormal
# 282	MURA_Finetune
# Prediction	Normal
# 283	MURA_Finetune
# Prediction	Abnormal
# 284	MURA_Finetune
# Prediction	Abnormal
# 285	MURA_Finetune
# Prediction	Abnormal
# 286	MURA_Finetune
# Prediction	Normal
# 287	MURA_Finetune
# Prediction	Abnormal
# 288	MURA_Finetune
# Prediction	Abnormal
# 289	MURA_Finetune
# Prediction	Abnormal
# 290	MURA_Finetune
# Prediction	Abnormal
# 291	MURA_Finetune
# Prediction	Abnormal
# 292	MURA_Finetune
# Prediction	Abnormal
# 293	MURA_Finetune
# Prediction	Abnormal
# 294	MURA_Finetune
# Prediction	Abnormal
# 295	MURA_Finetune
# Prediction	Abnormal
# 296	MURA_Finetune
# Prediction	Abnormal
# 297	MURA_Finetune
# Prediction	Abnormal
# 298	MURA_Finetune
# Prediction	Abnormal
# 299	MURA_Finetune
# Prediction	Normal
# 300	MURA_Finetune
# Prediction	Normal
# 301	MURA_Finetune
# Prediction	Normal
# 302	MURA_Finetune
# Prediction	Normal
# 303	MURA_Finetune
# Prediction	Normal
# 304	MURA_Finetune
# Prediction	Normal
# 305	MURA_Finetune
# Prediction	Abnormal
# 306	MURA_Finetune
# Prediction	Abnormal
# 307	MURA_Finetune
# Prediction	Normal
# 308	MURA_Finetune
# Prediction	Normal
# 309	MURA_Finetune
# Prediction	Abnormal
# 310	MURA_Finetune
# Prediction	Abnormal
# 311	MURA_Finetune
# Prediction	Abnormal
# 312	MURA_Finetune
# Prediction	Abnormal
# 313	MURA_Finetune
# Prediction	Abnormal
# 314	MURA_Finetune
# Prediction	Abnormal
# 315	MURA_Finetune
# Prediction	Abnormal
# 316	MURA_Finetune
# Prediction	Abnormal
# 317	MURA_Finetune
# Prediction	Abnormal
# 318	MURA_Finetune
# Prediction	Abnormal
# 319	MURA_Finetune
# Prediction	Abnormal
# 320	MURA_Finetune
# Prediction	Abnormal
# 321	MURA_Finetune
# Prediction	Abnormal
# 322	MURA_Finetune
# Prediction	Abnormal
# 323	MURA_Finetune
# Prediction	Abnormal
# 324	MURA_Finetune
# Prediction	Normal
# 325	MURA_Finetune
# Prediction	Normal
# 326	MURA_Finetune
# Prediction	Abnormal
# 327	MURA_Finetune
# Prediction	Normal
# 328	MURA_Finetune
# Prediction	Normal
# 329	MURA_Finetune
# Prediction	Abnormal
# 330	MURA_Finetune
# Prediction	Abnormal
# 331	MURA_Finetune
# Prediction	Normal
# 332	MURA_Finetune
# Prediction	Abnormal
# 333	MURA_Finetune
# Prediction	Normal
# 334	MURA_Finetune
# Prediction	Normal
# 335	MURA_Finetune
# Prediction	Normal
# 336	MURA_Finetune
# Prediction	Abnormal
# 337	MURA_Finetune
# Prediction	Normal
# 338	MURA_Finetune
# Prediction	Abnormal
# 339	MURA_Finetune
# Prediction	Normal
# 340	MURA_Finetune
# Prediction	Normal
# 341	MURA_Finetune
# Prediction	Normal
# 342	MURA_Finetune
# Prediction	Normal
# 343	MURA_Finetune
# Prediction	Normal
# 344	MURA_Finetune
# Prediction	Abnormal
# 345	MURA_Finetune
# Prediction	Abnormal
# 346	MURA_Finetune
# Prediction	Abnormal
# 347	MURA_Finetune
# Prediction	Abnormal
# 348	MURA_Finetune
# Prediction	Abnormal
# 349	MURA_Finetune
# Prediction	Abnormal
# 350	MURA_Finetune
# Prediction	Normal
# 351	MURA_Finetune
# Prediction	Normal
# 352	MURA_Finetune
# Prediction	Normal
# 353	MURA_Finetune
# Prediction	Normal
# 354	MURA_Finetune
# Prediction	Normal
# 355	MURA_Finetune
# Prediction	Normal
# 356	MURA_Finetune
# Prediction	Abnormal
# 357	MURA_Finetune
# Prediction	Normal
# 358	MURA_Finetune
# Prediction	Normal
# 359	MURA_Finetune
# Prediction	Abnormal
# 360	MURA_Finetune
# Prediction	Normal
# 361	MURA_Finetune
# Prediction	Abnormal
# 362	MURA_Finetune
# Prediction	Normal
# 363	MURA_Finetune
# Prediction	Normal
# 364	MURA_Finetune
# Prediction	Abnormal
# 365	MURA_Finetune
# Prediction	Abnormal
# 366	MURA_Finetune
# Prediction	Abnormal
# 367	MURA_Finetune
# Prediction	Normal
# 368	MURA_Finetune
# Prediction	Normal
# 369	MURA_Finetune
# Prediction	Normal
# 370	MURA_Finetune
# Prediction	Normal
# 371	MURA_Finetune
# Prediction	Normal
# 372	MURA_Finetune
# Prediction	Normal
# 373	MURA_Finetune
# Prediction	Normal
# 374	MURA_Finetune
# Prediction	Abnormal
# 375	MURA_Finetune
# Prediction	Normal
# 376	MURA_Finetune
# Prediction	Abnormal
# 377	MURA_Finetune
# Prediction	Normal
# 378	MURA_Finetune
# Prediction	Abnormal
# 379	MURA_Finetune
# Prediction	Abnormal
# 380	MURA_Finetune
# Prediction	Abnormal
# 381	MURA_Finetune
# Prediction	Abnormal
# 382	MURA_Finetune
# Prediction	Abnormal
# 383	MURA_Finetune
# Prediction	Abnormal
# 384	MURA_Finetune
# Prediction	Abnormal
# 385	MURA_Finetune
# Prediction	Abnormal
# 386	MURA_Finetune
# Prediction	Normal
# 387	MURA_Finetune
# Prediction	Normal
# 388	MURA_Finetune
# Prediction	Abnormal
# 389	MURA_Finetune
# Prediction	Normal
# 390	MURA_Finetune
# Prediction	Normal
# 391	MURA_Finetune
# Prediction	Normal
# 392	MURA_Finetune
# Prediction	Normal
# 393	MURA_Finetune
# Prediction	Abnormal
# 394	MURA_Finetune
# Prediction	Abnormal
# 395	MURA_Finetune
# Prediction	Abnormal
# 396	MURA_Finetune
# Prediction	Abnormal
# 397	MURA_Finetune
# Prediction	Abnormal
# 398	MURA_Finetune
# Prediction	Abnormal
# 399	MURA_Finetune
# Prediction	Abnormal
# 400	MURA_Finetune
# Prediction	Abnormal
# 401	MURA_Finetune
# Prediction	Abnormal
# 402	MURA_Finetune
# Prediction	Abnormal
# 403	MURA_Finetune
# Prediction	Abnormal
# 404	MURA_Finetune
# Prediction	Abnormal
# 405	MURA_Finetune
# Prediction	Abnormal
# 406	MURA_Finetune
# Prediction	Abnormal
# 407	MURA_Finetune
# Prediction	Normal
# 408	MURA_Finetune
# Prediction	Normal
# 409	MURA_Finetune
# Prediction	Abnormal
# 410	MURA_Finetune
# Prediction	Abnormal
# 411	MURA_Finetune
# Prediction	Abnormal
# 412	MURA_Finetune
# Prediction	Normal
# 413	MURA_Finetune
# Prediction	Abnormal
# 414	MURA_Finetune
# Prediction	Normal
# 415	MURA_Finetune
# Prediction	Normal
# 416	MURA_Finetune
# Prediction	Normal
# 417	MURA_Finetune
# Prediction	Normal
# 418	MURA_Finetune
# Prediction	Abnormal
# 419	MURA_Finetune
# Prediction	Abnormal
# 420	MURA_Finetune
# Prediction	Normal
# 421	MURA_Finetune
# Prediction	Abnormal
# 422	MURA_Finetune
# Prediction	Normal
# 423	MURA_Finetune
# Prediction	Abnormal
# 424	MURA_Finetune
# Prediction	Normal
# 425	MURA_Finetune
# Prediction	Normal
# 426	MURA_Finetune
# Prediction	Normal
# 427	MURA_Finetune
# Prediction	Abnormal
# 428	MURA_Finetune
# Prediction	Abnormal
# 429	MURA_Finetune
# Prediction	Normal
# 430	MURA_Finetune
# Prediction	Abnormal
# 431	MURA_Finetune
# Prediction	Abnormal
# 432	MURA_Finetune
# Prediction	Abnormal
# 433	MURA_Finetune
# Prediction	Abnormal
# 434	MURA_Finetune
# Prediction	Normal
# 435	MURA_Finetune
# Prediction	Normal
# 436	MURA_Finetune
# Prediction	Normal
# 437	MURA_Finetune
# Prediction	Normal
# 438	MURA_Finetune
# Prediction	Normal
# 439	MURA_Finetune
# Prediction	Abnormal
# 440	MURA_Finetune
# Prediction	Abnormal
# 441	MURA_Finetune
# Prediction	Abnormal
# 442	MURA_Finetune
# Prediction	Abnormal
# 443	MURA_Finetune
# Prediction	Abnormal
# 444	MURA_Finetune
# Prediction	Abnormal
# 445	MURA_Finetune
# Prediction	Normal
# 446	MURA_Finetune
# Prediction	Normal
# 447	MURA_Finetune
# Prediction	Normal
# 448	MURA_Finetune
# Prediction	Abnormal
# 449	MURA_Finetune
# Prediction	Normal
# 450	MURA_Finetune
# Prediction	Normal
# 451	MURA_Finetune
# Prediction	Abnormal
# 452	MURA_Finetune
# Prediction	Abnormal
# 453	MURA_Finetune
# Prediction	Abnormal
# 454	MURA_Finetune
# Prediction	Abnormal
# 455	MURA_Finetune
# Prediction	Abnormal
# 456	MURA_Finetune
# Prediction	Normal
# 457	MURA_Finetune
# Prediction	Normal
# 458	MURA_Finetune
# Prediction	Abnormal
# 459	MURA_Finetune
# Prediction	Normal
# 460	MURA_Finetune
# Prediction	Normal
# 461	MURA_Finetune
# Prediction	Normal
# 462	MURA_Finetune
# Prediction	Abnormal
# 463	MURA_Finetune
# Prediction	Abnormal
# 464	MURA_Finetune
# Prediction	Abnormal
# 465	MURA_Finetune
# Prediction	Normal
# 466	MURA_Finetune
# Prediction	Normal
# 467	MURA_Finetune
# Prediction	Normal
# 468	MURA_Finetune
# Prediction	Normal
# 469	MURA_Finetune
# Prediction	Normal
# 470	MURA_Finetune
# Prediction	Abnormal
# 471	MURA_Finetune
# Prediction	Normal
# 472	MURA_Finetune
# Prediction	Abnormal
# 473	MURA_Finetune
# Prediction	Abnormal
# 474	MURA_Finetune
# Prediction	Abnormal
# 475	MURA_Finetune
# Prediction	Abnormal
# 476	MURA_Finetune
# Prediction	Normal
# 477	MURA_Finetune
# Prediction	Abnormal
# 478	MURA_Finetune
# Prediction	Abnormal
# 479	MURA_Finetune
# Prediction	Abnormal
# 480	MURA_Finetune
# Prediction	Abnormal
# 481	MURA_Finetune
# Prediction	Abnormal
# 482	MURA_Finetune
# Prediction	Abnormal
# 483	MURA_Finetune
# Prediction	Abnormal
# 484	MURA_Finetune
# Prediction	Abnormal
# 485	MURA_Finetune
# Prediction	Abnormal
# 486	MURA_Finetune
# Prediction	Abnormal
# 487	MURA_Finetune
# Prediction	Abnormal
# 488	MURA_Finetune
# Prediction	Abnormal
# 489	MURA_Finetune
# Prediction	Abnormal
# 490	MURA_Finetune
# Prediction	Normal
# 491	MURA_Finetune
# Prediction	Normal
# 492	MURA_Finetune
# Prediction	Normal
# 493	MURA_Finetune
# Prediction	Normal
# 494	MURA_Finetune
# Prediction	Abnormal
# 495	MURA_Finetune
# Prediction	Abnormal
# 496	MURA_Finetune
# Prediction	Abnormal
# 497	MURA_Finetune
# Prediction	Normal
# 498	MURA_Finetune
# Prediction	Normal
# 499	MURA_Finetune
# Prediction	Normal
# 500	MURA_Finetune
# Prediction	Abnormal
